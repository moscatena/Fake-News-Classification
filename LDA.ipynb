# %% [markdown]
# # Fake News Detection
#
# **Author**: Marcelo Scatena
# ***
# March 2022

# %% [markdown]
# # Latent Dirichlet Allocation

# %% [markdown]
# LDA was first introduced in a 2003 paper titled [Latent Dirichlet Allocation](https://web.archive.org/web/20120207011313/http://jmlr.csail.mit.edu/papers/volume3/blei03a/blei03a.pdf). There the authors describe lda as 'a generative probabilistic model for collections of discrete data such as text corpora.'. LDA is an unsuperversid topic modeling technique. Given a corpus and a number of topics, it breaks down the corpus into said amount of topics, and calculates the probability of each word to be belonging of one topic or another. With it, we can better understand what the topics of the corpus are constructed from.

# %%
#Dependencies

import pandas as pd

import gensim #the library for Topic modelling
from gensim.models.ldamulticore import LdaMulticore
from gensim import corpora, models
import pyLDAvis.gensim_models #LDA visualization library

from nltk.corpus import stopwords
import string
from nltk.stem.wordnet import WordNetLemmatizer
import regex as re

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer

import warnings
warnings.simplefilter('ignore')
from itertools import chain

# %% [markdown]
# ## Import, clean and join data

# %%
col_names = ['ID', 'label', 'statement', 'subject', 'speaker', 'speaker\'s title', 'state', 'party', 'barely true', 'false', 'half true', 'mostly true', 'pants on fire', 'context', 'justification']
raw_train = pd.read_csv('data/train2.tsv', sep='\t', names=col_names)
raw_test = pd.read_csv('data/test2.tsv', sep='\t', names=col_names)
raw_val = pd.read_csv('data/val2.tsv', sep='\t', names=col_names)

# %%
df_train = raw_train.copy()
df_val = raw_val.copy()
df_test = raw_test.copy()

# %%
def drop_na(df):
    df = df.dropna(subset=['statement'], axis=0)
    return df

def drop_duplicated(df):
    df = df.drop_duplicates()
    return df

def label(df):
    df['label'] = df['label'].map({'true': 1,
                                     'mostly-true': 1,
                                     'half-true': 1,
                                     'false': 0,
                                     'barely-true': 0,
                                     'pants-fire': 0})
    return df

def drop_features(df):
    df = df[['statement','label']]
    return df

def reset_index(df):
    df['statement'] = df['statement'].apply(lambda x: x.lower())
    return df

def clean(text):
    text=text.lower()
    stp=set(stopwords.words("english"))
    stp.update(['say', 'percent', 'state', 'year',
               'said', 'people', 'one'])
    placesp = re.compile('[/(){}\[\]\|@,;]')
    removech= re.compile('[^0-9a-z #+_]')
    st=WordNetLemmatizer()
    text=re.sub(placesp,' ',text)
    text=re.sub(removech,' ',text)
    text=text.split()
    text=[w for w in text if not w in stp]
    text=[st.lemmatize(w) for w in text]
    text=[w for w in text if not w in stp]
    text=" ".join(text)
    text = text.translate(str.maketrans("", "", string.punctuation))
    return text

def clean_df(df):
    df['statement'] = df['statement'].apply(lambda x: clean(x))
    return df

def lower_case(df):
    df = df.reset_index(drop=True)
    return df

# %%
cleaning_pipeline = Pipeline(steps=[
    ('drop_na', FunctionTransformer(drop_na)),
    ('drop_duplicated', FunctionTransformer(drop_duplicated)),
    ('label', FunctionTransformer(label)),
    ('drop_features', FunctionTransformer(drop_features)),
    ('reset_index', FunctionTransformer(reset_index)),
    ('lower_case', FunctionTransformer(lower_case)),
    ('clean_df', FunctionTransformer(clean_df))
])

# %%
df_train_clean = cleaning_pipeline.fit_transform(df_train)
df_val_clean = cleaning_pipeline.transform(df_val)
df_test_clean = cleaning_pipeline.transform(df_test)

# %%
df_all = pd.concat([df_train_clean, df_val_clean, df_test_clean])

# %%
df_all.head()
# Out:
#                                            statement  label
# 0  annies list political group support third trim...      0
# 1  decline coal start started natural gas took st...      1
# 2  hillary clinton agrees john mccain voting give...      1
# 3  health care reform legislation likely mandate ...      0
# 4               economic turnaround started end term      1

# %% [markdown]
# ##### Split text into tokens

# %%
df_all_split = df_all['statement'].apply(lambda x : x.split())

# %% [markdown]
# ##### Create Dictionary from the statements

# %%
dictionary = corpora.Dictionary(df_all_split)
#Total number of non-zeroes in the BOW matrix (sum of the number of unique words per document over the entire corpus).
print(dictionary.num_nnz)
# Out:
# 130152

# %% [markdown]
# ##### Create statement term matrix

# %%
doc_term_matrix = [dictionary.doc2bow(doc) for doc in df_all_split]
print(len(doc_term_matrix))
# Out:
# 12791

# %% [markdown]
# ##### Instantiate LDA model

# %%
lda = gensim.models.ldamodel.LdaModel

# %% [markdown]
# ##### Fit LDA model on the dataset

# %%
num_topics=2
ldamodel = lda(doc_term_matrix,num_topics=num_topics,id2word=dictionary,passes=50,minimum_probability=0)

# %% [markdown]
# ##### Print the topics identified by LDA model

# %%
ldamodel.print_topics(num_topics=num_topics)
# Out:
# [(0,
#   '0.009*"obama" + 0.007*"president" + 0.005*"clinton" + 0.005*"american" + 0.005*"united" + 0.005*"country" + 0.005*"u" + 0.005*"barack" + 0.005*"law" + 0.004*"right"'),
#  (1,
#   '0.015*"tax" + 0.012*"000" + 0.010*"job" + 0.010*"million" + 0.009*"health" + 0.008*"care" + 0.007*"1" + 0.007*"billion" + 0.006*"budget" + 0.006*"cut"')]

# %% [markdown]
# ##### Visualize the LDA model results

# %%
lda_display = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1557224179414660165887004655"></div>
# <script type="text/javascript">
#
# var ldavis_el1557224179414660165887004655_data = {"mdsDat": {"x": [-0.04881035287360906, 0.04881035287360906], "y": [0.1540820131117245, -0.1540820131117245], "topics": [1, 2], "cluster": [1, 1], "Freq": [44.07723562316397, 55.92276437683602]}, "tinfo": {"Term": ["tax", "000", "job", "million", "health", "care", "1", "billion", "clinton", "budget", "united", "cut", "voted", "plan", "woman", "city", "right", "pay", "money", "cost", "hillary", "trump", "gun", "world", "2", "spending", "10", "dollar", "abortion", "democrat", "clinton", "gun", "hillary", "trump", "united", "woman", "donald", "world", "city", "illegal", "war", "court", "crime", "voter", "border", "iraq", "right", "immigrant", "abortion", "white", "military", "use", "iran", "supreme", "immigration", "show", "case", "voting", "black", "police", "think", "party", "force", "election", "obama", "country", "president", "law", "barack", "american", "child", "even", "u", "texas", "get", "america", "time", "vote", "would", "tax", "job", "000", "health", "million", "care", "billion", "1", "budget", "cut", "pay", "spending", "plan", "cost", "money", "2", "debt", "dollar", "medicare", "income", "increase", "governor", "insurance", "obamacare", "scott", "per", "average", "10", "3", "5", "voted", "democrat", "office", "senate", "republican", "new", "rate", "federal", "would", "bill", "government", "time", "last", "u", "ob
# %%
doc_term_matrix = [dictionary.doc2bow(doc) for doc in df_all_split]
print(len(doc_term_matrix))

lda = gensim.models.ldamodel.LdaModel

num_topics=2
ldamodel = lda(doc_term_matrix,num_topics=num_topics,id2word=dictionary,passes=50,minimum_probability=0)
# Out:
# 12791

# %%
ldamodel.print_topics(num_topics=num_topics)
# Out:
# [(0,
#   '0.014*"obama" + 0.012*"president" + 0.011*"health" + 0.010*"care" + 0.008*"bill" + 0.007*"republican" + 0.007*"barack" + 0.007*"law" + 0.007*"voted" + 0.005*"clinton"'),
#  (1,
#   '0.017*"tax" + 0.011*"job" + 0.011*"million" + 0.008*"billion" + 0.007*"budget" + 0.006*"new" + 0.006*"cut" + 0.006*"texas" + 0.006*"rate" + 0.006*"school"')]

# %%
lda_display = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1557224178672428485280374337"></div>
# <script type="text/javascript">
#
# var ldavis_el1557224178672428485280374337_data = {"mdsDat": {"x": [-0.055553669947719014, 0.055553669947719014], "y": [0.17536896984649747, -0.17536896984649747], "topics": [1, 2], "cluster": [1, 1], "Freq": [47.63226719918203, 52.36773280081797]}, "tinfo": {"Term": ["tax", "obama", "president", "health", "job", "million", "care", "bill", "republican", "billion", "barack", "law", "voted", "budget", "cut", "rate", "school", "clinton", "cost", "democrat", "money", "spending", "want", "senate", "obamacare", "vote", "dollar", "house", "insurance", "hillary", "obama", "health", "president", "care", "barack", "law", "republican", "clinton", "voted", "vote", "senate", "hillary", "trump", "gun", "house", "abortion", "campaign", "donald", "congress", "candidate", "democrat", "bill", "mccain", "0", "rep", "never", "john", "court", "election", "want", "obamacare", "insurance", "romney", "medicare", "security", "support", "american", "plan", "would", "time", "tax", "job", "million", "billion", "rate", "budget", "school", "cut", "cost", "spending", "dollar", "average", "income", "debt", "per", "increase", "city", "county", "unemployment", "5", "world", "highest", "nearly", "3", "50", "student", "education", "today", "4", "oil", "scott", "family", "le", "money", "nation", "20", "business", "gov", "texas", "pay", "new", "since", "every", "last", "country", "federal", "time", "wisconsin", "would", "american", "government"], "Freq": [1169.0, 862.0, 738.0, 729.0, 763.0, 749.0, 627.0, 528.0, 465.0, 530.0, 450.0, 427.0, 413.0, 466.0, 440.0, 404.0, 393.0, 327.0, 326.0, 267.0, 332.0, 298.0, 259.0, 245.0, 252.0, 242.0, 276.0, 238.0, 238.0, 222.0, 861.4505135559323, 729.0601058362893, 738.1880309198121, 626.5690595480187, 449.893763619388, 426.9791328893745, 464.98285133542134, 326.47318204663185, 412.4836101201699, 241.7011759573259, 245.26331863099205, 222.43712763112893, 220.67834340158498, 219.21651882020694, 237.6495732679312, 183.99321851484808, 209.38602202396223, 179.68130182173377, 214.24072833302256, 182.57258706320616, 266.7458015505126, 526.8039058706454, 149.61448072101834, 174.47843236130865, 143.1232998192363, 207.7940182938804, 168.5794580665934, 131.12165932377007, 165.54554715012063, 258.06119722450126, 250.65611942508227, 237.22565314571477, 168.3663168404748, 235.10169698865693, 206.25770649403685, 227.9023190757913, 316.2838030265534, 253.20330176991297, 309.02203007201575, 205.10611490262855, 1169.124539191528, 762.611006398964, 748.9822717849977, 530.3919128197284, 404.19596614681046, 465.86667203638734, 393.30096480321964, 439.83143863681715,
ack", "men", "weapon", "crist", "charlie", "killed", "secretary", "another", "trying", "ive", "officer", "fewer", "tell", "politician", "johnson", "open", "birth", "changed", "earmark", "reserve", "belief", "allowing", "overseas", "mccain", "terrorist", "john", "iraq", "called", "control", "woman", "want", "war", "life", "gas", "never", "right", "even", "united", "gun", "health", "care", "insurance", "reform", "class", "coverage", "property", "mandate", "premium", "corporate", "provide", "employer", "access", "doctor", "millionaire", "subsidy", "hampshire", "bargaining", "95", "illinois", "foundation", "caused", "collective", "bipartisan", "28", "covered", "mortgage", "nelson", "hand", "exchange", "passed", "obamacare", "raise", "plan", "senate", "bill", "senior", "tax", "signed", "small", "pay", "middle", "law", "medicare", "lower", "member", "new", "would", "voted", "cut ...

# %% [markdown]
# #### Split data into true and fake statements

# %%
df_all_true = df_all[df_all['label']==1]
df_all_fake = df_all[df_all['label']==0]

# %%
df_all_true_split = df_all_true['statement'].apply(lambda x : x.split())
df_all_fake_split = df_all_fake['statement'].apply(lambda x : x.split())
df_all_true_split = df_all_true_split.apply(lambda x: remove_stopwords_row(x))
df_all_fake_split = df_all_fake_split.apply(lambda x: remove_stopwords_row(x))

# %% [markdown]
# #### True statements, 2 topics

# %%
doc_term_matrix = [dictionary.doc2bow(doc) for doc in df_all_true_split]
print(len(doc_term_matrix))

lda = gensim.models.ldamodel.LdaModel

num_topics=2
ldamodel = lda(doc_term_matrix,num_topics=num_topics,id2word=dictionary,passes=50,minimum_probability=0)
# Out:
# 7134

# %%
ldamodel.print_topics(num_topics=num_topics)
# Out:
# [(0,
#   '0.011*"obama" + 0.010*"president" + 0.008*"republican" + 0.006*"bill" + 0.006*"voted" + 0.006*"barack" + 0.005*"american" + 0.005*"law" + 0.004*"time" + 0.004*"clinton"'),
#  (1,
#   '0.014*"tax" + 0.010*"million" + 0.010*"job" + 0.008*"health" + 0.007*"new" + 0.006*"rate" + 0.006*"billion" + 0.006*"budget" + 0.006*"care" + 0.006*"cut"')]

# %%
lda_display = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1557224179412847843541945498"></div>
# <script type="text/javascript">
#
# var ldavis_el1557224179412847843541945498_data = {"mdsDat": {"x": [-0.04796153707220928, 0.04796153707220928], "y": [0.1514025150187813, -0.1514025150187813], "topics": [1, 2], "cluster": [1, 1], "Freq": [42.13243846577709, 57.86756153422291]}, "tinfo": {"Term": ["tax", "obama", "president", "million", "job", "republican", "health", "voted", "barack", "rate", "billion", "budget", "care", "cut", "school", "clinton", "senate", "vote", "gun", "trump", "democrat", "bill", "pay", "spending", "house", "candidate", "campaign", "donald", "average", "nation", "obama", "president", "republican", "barack", "clinton", "gun", "vote", "senate", "trump", "candidate", "campaign", "donald", "hillary", "democrat", "0", "election", "mccain", "house", "war", "never", "john", "party", "member", "voter", "sen", "iraq", "court", "military", "immigration", "congress", "voted", "democratic", "bill", "law", "bush", "support", "american", "time", "would", "tax", "job", "million", "billion", "rate", "health", "budget", "cut", "school", "care", "average", "pay", "spending", "cost", "debt", "income", "dollar", "nation", "per", "highest", "increase", "family", "insurance", "unemployment", "5", "education", "student", "wage", "medicare", "trillion", "50", "le", "program",
471068896492, 103.98567308480146, 84.06357195282611, 79.80269664244967, 62.00704576038006, 53.83768569848883, 65.80038767372316, 89.81520441318219, 61.83147260876907, 48.064602849628365, 42.52130218761985, 81.61686187573991, 75.69725490402814, 38.614796670657476, 109.20923187720976, 47.64287252822379, 43.23435326492034, 40.07238138655991, 35.10443610680671, 33.87142217215844, 66.20645484215672, 40.2149036360399, 41.95656348895048, 46.19244372905835, 27.7194461193113, 37.30452603525665, 31.942351377353383, 25.008840995521776, 22.7405846665333, 22.139528171274346, 23.457218042628934, 43.99495805659842, 40.41043117576991, 31.43645728958719, 110.53204345201137, 31.8101101517984, 184.12560930348647, 282.95669586896616, 52.02600897647793, 307.9781327826263, 43.83459665358686, 72.33430391006529, 73.39687507740288, 96.23503687545524, 58.51509149914313, 60.71805479003539, 55.95609747823874, 66.50065474773047, 56.21846180114349, 74.8979508683385, 66.2026526284113, 63.82487431376292, 55.242236187963584, 64.77061277015311, 62.211636110955304, 54.72394294806717], "Total": [452.0, 358.0, 332.0, 279.0, 239.0, 354.0, 207.0, 206.0, 186.0, 433.0, 219.0, 110.0, 170.0, 104.0, 150.0, 115.0, 137.0, 90.0, 149.0, 131.0, 84.0, 128.0, 82.0, 80.0, 120.0, 176.0, 115.0, 76.0, 106.0, 1 ...

# %% [markdown]
# #### True statements, 8 topics

# %%
doc_term_matrix = [dictionary.doc2bow(doc) for doc in df_all_true_split]
print(len(doc_term_matrix))

lda = gensim.models.ldamodel.LdaModel

num_topics=8
ldamodel = lda(doc_term_matrix,num_topics=num_topics,id2word=dictionary,passes=50,minimum_probability=0)
# Out:
# 7134

# %%
ldamodel.print_topics(num_topics=num_topics)
# Out:
# [(0,
#   '0.012*"0" + 0.012*"gov" + 0.011*"scott" + 0.010*"rick" + 0.010*"romney" + 0.010*"illegal" + 0.010*"governor" + 0.009*"mitt" + 0.006*"walker" + 0.006*"perry"'),
#  (1,
#   '0.021*"clinton" + 0.015*"hillary" + 0.013*"john" + 0.012*"iraq" + 0.012*"mccain" + 0.011*"war" + 0.010*"american" + 0.007*"crime" + 0.006*"death" + 0.006*"marijuana"'),
#  (2,
#   '0.013*"republican" + 0.012*"trump" + 0.010*"bill" + 0.010*"donald" + 0.009*"law" + 0.009*"senate" + 0.009*"vote" + 0.009*"security" + 0.008*"democrat" + 0.008*"house"'),
#  (3,
#   '0.025*"obama" + 0.024*"job" + 0.020*"million" + 0.020*"president" + 0.013*"billion" + 0.012*"barack" + 0.011*"debt" + 0.010*"time" + 0.010*"since" + 0.010*"spending"'),
#  (4,
#   '0.011*"republican" + 0.006*"even" + 0.006*"since" + 0.006*"reagan" + 0.006*"used" + 0.005*"world" + 0.005*"budget" + 0.005*"voted" + 0.005*"party" + 0.005*"time"'),
#  (5,
#   '0.020*"rate" + 0.018*"school" + 0.015*"country" + 0.014*"texas" + 0.012*"nation" + 0.011*"highest" + 0.011*"student" + 0.009*"college" + 0.009*"georgia" + 0.008*"new"'),
#  (6,
#   '0.008*"check" + 0.007*"act" + 0.007*"would" + 0.007*"company" + 0.006*"abortion" + 0.006*"austin" + 0.006*"thousand" + 0.006*"background" + 0.006*"worth" + 0.005*"woman"'),
#  (7,
#   '0.050*"tax" + 0.025*"health" + 0.018*"care" + 0.013*"pay" + 0.011*"income" + 0.011*"cut" + 0.011*"million" + 0.010*"family" + 0.010*"american" + 0.010*"insurance"')]

# %%
lda_display = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el
"time", "3", "last", "government", "federal", "new", "reagan", "killed", "chris", "christie", "rubio", "marco", "ronald", "charlie", "planned", "corporate", "parenthood", "includes", "drilling", "word", "loophole", "nominee", "unemployed", "representative", "ii", "latino", "98", "virtually", "recently", "died", "israel", "burden", "probably", "forty", "hearing", "reid", "crist", "greater", "veteran", "used", "rape", "balanced", "republican", "party", "even", "issue", "world", "policy", "since", "get", "voted", "budget", "united", "war", "time", "country", "federal", "government", "vote", "american", "highest", "student", "college", "lowest", "rhode", "island", "population", "university", "rank", "cant", "best", "hispanic", "graduate", "recovery", "28", "gap", "loan", "retiree", "degree", "registered", "schola ...

# %% [markdown]
# #### Fake statements, 8 topics

# %%
doc_term_matrix = [dictionary.doc2bow(doc) for doc in df_all_fake_split]
print(len(doc_term_matrix))

lda = gensim.models.ldamodel.LdaModel

num_topics=8
ldamodel = lda(doc_term_matrix,num_topics=num_topics,id2word=dictionary,passes=50,minimum_probability=0)
# Out:
# 5657

# %%
ldamodel.print_topics(num_topics=num_topics)
# Out:
# [(0,
#   '0.008*"work" + 0.008*"united" + 0.006*"city" + 0.006*"candidate" + 0.006*"attack" + 0.006*"oil" + 0.005*"congress" + 0.005*"austin" + 0.005*"terrorist" + 0.005*"clinton"'),
#  (1,
#   '0.010*"country" + 0.008*"romney" + 0.007*"woman" + 0.007*"number" + 0.007*"law" + 0.007*"gun" + 0.007*"mitt" + 0.006*"trump" + 0.005*"texas" + 0.005*"america"'),
#  (2,
#   '0.022*"president" + 0.020*"obama" + 0.011*"barack" + 0.006*"would" + 0.006*"job" + 0.005*"abortion" + 0.005*"college" + 0.005*"obamas" + 0.004*"america" + 0.004*"muslim"'),
#  (3,
#   '0.008*"job" + 0.007*"island" + 0.007*"rhode" + 0.007*"republican" + 0.005*"child" + 0.005*"bill" + 0.005*"national" + 0.005*"dont" + 0.004*"gun" + 0.004*"almost"'),
#  (4,
#   '0.039*"obama" + 0.029*"president" + 0.023*"barack" + 0.012*"illegal" + 0.010*"since" + 0.010*"bush" + 0.009*"immigrant" + 0.009*"time" + 0.006*"per" + 0.006*"first"'),
#  (5,
#   '0.013*"security" + 0.012*"social" + 0.012*"clinton" + 0.011*"new" + 0.009*"million" + 0.009*"job" + 0.008*"hillary" + 0.007*"20" + 0.006*"american" + 0.006*"obamacare"'),
#  (6,
#   '0.039*"tax" + 0.032*"health" + 0.029*"care" + 0.013*"plan" + 0.012*"pay" + 0.011*"government" + 0.010*"bill" + 0.010*"federal" + 0.009*"would" + 0.009*"voted"'),
#  (7,
#   '0.016*"wisconsin" + 0.013*"scott" + 0.012*"job" + 0.012*"school" + 0.011*"gov" + 0.011*"public" + 0.009*"billion" + 0.009*"walker" + 0.008*"million" + 0.008*"budget"')]

# %%
lda_display = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1557224180158632961865521945"></div>
# <script type="text/javascript">
#
# var ldavis_el1557224180158632961865521945_data = {"mdsDat": {"x": [-0.1582993402524278, 0.04755292735962711, 0.2400712042597809, -0.24108413579438018, 0.2410946997354795, -0.01676742304679788, -0.19194534386626505, 0.07937741160498342], "y": [0.22221246398736882, 0.2385888337798507, -0.07543375417567366, 0.029164890999638197, 0.12611980129603934, -0.05290046704893832, -0.22215581049448274, -0.26559595834380256], "topics": [1, 2, 3, 4, 5, 6, 7, 8], "cluster": [1, 1, 1, 1, 1, 1, 1, 1], "Freq":